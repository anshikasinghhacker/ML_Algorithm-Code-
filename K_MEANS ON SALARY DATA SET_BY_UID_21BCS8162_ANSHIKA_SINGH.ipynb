# %% [markdown]
# <a href="https://colab.research.google.com/github/anshikasinghhacker/BlogWesbite/blob/master/K_MEANS%20ON%20SALARY%20DATA%20SET_BY_UID_21BCS8162_ANSHIKA_SINGH.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-9b2176f8-6bb0-49e0-a308-7d1ecf2bd91f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9b2176f8-6bb0-49e0-a308-7d1ecf2bd91f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from sklearn .cluster import KMeans
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline
df=pd.read_csv("Salary_Data.csv")

# %%
plt.scatter(df["YearsExperience"],df["Salary"])

# %%
km=KMeans(n_clusters=3)
ypred=km.fit_predict(df[["YearsExperience","Salary"]])
df
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
df["Cluster"] = ypred
df
# Out:
#     YearsExperience    Salary  Cluster
# 0               1.1   39343.0        0
# 1               1.3   46205.0        0
# 2               1.5   37731.0        0
# 3               2.0   43525.0        0
# 4               2.2   39891.0        0
# 5               2.9   56642.0        0
# 6               3.0   60150.0        0
# 7               3.2   54445.0        0
# 8               3.2   64445.0        0
# 9               3.7   57189.0        0
# 10              3.9   63218.0        0
# 11              4.0   55794.0        0
# 12              4.0   56957.0        0
# 13              4.1   57081.0        0
# 14              4.5   61111.0        0
# 15              4.9   67938.0        0
# 16              5.1   66029.0        0
# 17              5.3   83088.0        1
# 18              5.9   81363.0        1
# 19              6.0   93940.0        1
# 20              6.8   91738.0        1
# 21              7.1   98273.0        1
# 22              7.9  101302.0        1
# ...

# %%
df1=df[df.Cluster==0]
df2=df[df.Cluster==1]
df3=df[df.Cluster==2]
print(df1,df2,df3)
# Out:
#     YearsExperience   Salary  Cluster
# 0               1.1  39343.0        0
# 1               1.3  46205.0        0
# 2               1.5  37731.0        0
# 3               2.0  43525.0        0
# 4               2.2  39891.0        0
# 5               2.9  56642.0        0
# 6               3.0  60150.0        0
# 7               3.2  54445.0        0
# 8               3.2  64445.0        0
# 9               3.7  57189.0        0
# 10              3.9  63218.0        0
# 11              4.0  55794.0        0
# 12              4.0  56957.0        0
# 13              4.1  57081.0        0
# 14              4.5  61111.0        0
# 15              4.9  67938.0        0
# 16              5.1  66029.0        0     YearsExperience    Salary  Cluster
# 17              5.3   83088.0        1
# 18              5.9   81363.0        1
# 19              6.0   93940.0        1
# 20              6.8   91738.0        1
# 21              7.1   98273.0        1
# ...

# %%
plt.scatter(df1.YearsExperience,df1["Salary"],color="green")
plt.scatter(df2.YearsExperience,df2["Salary"],color="blue")
plt.scatter(df3.YearsExperience,df3["Salary"],color="yellow")
plt.xlabel("YearsExperience")
plt.ylabel("Salary")
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>
